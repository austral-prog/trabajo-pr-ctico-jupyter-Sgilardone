# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).

# %% [markdown]
# ---

# %% [markdown]
# # [EXERCISE 1]
# ## Santiago Gilardone sgilardone@mail.austral.edu.ar
#
# ![image.png](attachment:0df7d987-7a40-44a1-86f8-8f0ef6431e85.png)
# #### This is the breed and colour of my dog.

# %% [markdown]
# # [EXERCISE 2]

# %%
def rectangle_area (width,height):
    area=(width*height)
    print(f"The area of a rectangle with width {width} and height {height} is {area}")

# %% [markdown]
# # [EXERCISE 3]

# %%
rectangle_area(3,4)
rectangle_area(5,10)
rectangle_area(8,2)
# Out:
# The area of a rectangle with width 3 and height 4 is 12
# The area of a rectangle with width 5 and height 10 is 50
# The area of a rectangle with width 8 and height 2 is 16

# %% [markdown]
# # [EXERCISE 5]

# %%
a=3
b=7

# %% [markdown]
# ## SUMA

# %%
print(a+b)
# Out:
# 10

# %% [markdown]
# ## RESTA

# %%
print(a-b)
# Out:
# -4

# %% [markdown]
# ## MULTIPLICACION

# %%
print(a*b)
# Out:
# 21

# %% [markdown]
# ## DIVISION

# %%
print(a/b)
# Out:
# 0.42857142857142855
